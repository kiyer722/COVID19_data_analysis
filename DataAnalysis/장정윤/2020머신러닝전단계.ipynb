# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeongyoon-Jang/covid19_data_analysis/blob/main/2020%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EC%A0%84%EB%8B%A8%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (6,783 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib as mpl
from sklearn.preprocessing import MinMaxScaler

# %%
da20 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/seouldata/data2020_3.csv")
da20
# Out:
#       기준_년_코드  기준_분기_코드    상권_코드  ... 총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 0        2020         3  1001496  ...   15904.0       0.0         1
# 1        2020         3  1001495  ...   24375.0      22.0         1
# 2        2020         3  1001494  ...   32935.0       5.0         1
# 3        2020         3  1001493  ...    6054.0       8.0         1
# 4        2020         3  1001492  ...  104830.0       0.0         1
# ...       ...       ...      ...  ...       ...       ...       ...
# 4450     2020         1  1000005  ...    1797.0      41.0         1
# 4451     2020         1  1000004  ...      56.0      41.0         1
# 4452     2020         1  1000003  ...    3686.0       5.0         1
# 4453     2020         1  1000002  ...     201.0       5.0         0
# 4454     2020         1  1000001  ...     842.0      26.0         1
#
# [4455 rows x 14 columns]

# %%
# 변수별 그래프

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '총_유동인구_수',shade=True)
facet.set(xlim=(da20['총_유동인구_수'].min(),da20['총_유동인구_수'].max()))
facet.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '당월_매출_금액',shade=True)
facet.set(xlim=(da20['당월_매출_금액'].min(),da20['당월_매출_금액'].max()))
facet.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '당월_매출_건수',shade=True)
facet.set(xlim=(da20['당월_매출_건수'].min(),da20['당월_매출_건수'].max()))
facet.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '점포_수',shade=True)
facet.set(xlim=(da20['점포_수'].min(),da20['점포_수'].max()))
facet.add_legend()

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '개업_점포_수',shade=True)
facet.set(xlim=(da20['개업_점포_수'].min(),da20['개업_점포_수'].max()))
facet.add_legend()

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '폐업_점포_수',shade=True)
facet.set(xlim=(da20['폐업_점포_수'].min(),da20['폐업_점포_수'].max()))
facet.add_legend()

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '집객시설_수',shade=True)
facet.set(xlim=(da20['집객시설_수'].min(),da20['집객시설_수'].max()))
facet.add_legend()

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '총_직장_인구_수',shade=True)
facet.set(xlim=(da20['총_직장_인구_수'].min(),da20['총_직장_인구_수'].max()))
facet.add_legend()

# %%
facet=sns.FacetGrid(da20, hue='상권_변화_지표', aspect=4)
facet.map(sns.kdeplot, '아파트_단지_수',shade=True)
facet.set(xlim=(da20['아파트_단지_수'].min(),da20['아파트_단지_수'].max()))
facet.add_legend()

# %%
# train과 test를 7:3으로 분할

# %%
test = da20.sample(frac=0.3,replace=False,random_state=1)
train = da20.sample(frac=0.7,replace=False,random_state=7)

# %%
train = train.drop(['기준_년_코드','기준_분기_코드','상권_코드','상권_코드_명'], axis=1)
train
# Out:
#        총_유동인구_수      당월_매출_금액   당월_매출_건수  ...  총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 1441   136930.0  1.591010e+09   139149.0  ...      180.0       7.0         1
# 2948   559540.0  2.289313e+09   153182.0  ...       56.0      17.0         1
# 4092   136542.0  6.603709e+08    36717.0  ...      342.0       4.0         1
# 640   1317985.0  1.079204e+10   508884.0  ...     1850.0      88.0         1
# 4446    27732.0  5.732069e+09   138971.0  ...     2703.0       1.0         1
# ...         ...           ...        ...  ...        ...       ...       ...
# 1194   387674.0  5.931738e+09   666075.0  ...      150.0       8.0         1
# 2876   258770.0  6.950230e+09   338597.0  ...      443.0       7.0         1
# 4336  1157221.0  2.449002e+09   180381.0  ...      208.0      15.0         1
# 1824    69990.0  4.589869e+11  1828533.0  ...      392.0       1.0         1
# 1879  1402006.0  5.054020e+10  1979664.0  ...     2284.0      25.0         1
#
# [3118 rows x 10 columns]

# %%
# minmaxscaler을 이용해 모든 값을 0과 1사이로 변환

# %%
scaler = MinMaxScaler()
train[:] = scaler.fit_transform(train[:])

# %%
train
# Out:
#       총_유동인구_수  당월_매출_금액  당월_매출_건수  ...  총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 1441  0.023829  0.003046  0.009839  ...   0.001717  0.014831       1.0
# 2948  0.102332  0.004390  0.010833  ...   0.000534  0.036017       1.0
# 4092  0.023757  0.001256  0.002584  ...   0.003262  0.008475       1.0
# 640   0.243219  0.020746  0.036029  ...   0.017648  0.186441       1.0
# 4446  0.003545  0.011013  0.009827  ...   0.025785  0.002119       1.0
# ...        ...       ...       ...  ...        ...       ...       ...
# 1194  0.070407  0.011397  0.047163  ...   0.001431  0.016949       1.0
# 2876  0.046462  0.013356  0.023967  ...   0.004226  0.014831       1.0
# 4336  0.213356  0.004697  0.012760  ...   0.001984  0.031780       1.0
# 1824  0.011394  0.882935  0.129503  ...   0.003739  0.002119       1.0
# 1879  0.258827  0.097210  0.140208  ...   0.021788  0.052966       1.0
#
# [3118 rows x 10 columns]

# %%
train_data=train.drop('상권_변화_지표',axis=1)
train_data.shape
# Out:
# (3118, 9)

# %%
test.shape
# Out:
# (1336, 14)

# %%
train_data.head()
# Out:
#       총_유동인구_수  당월_매출_금액  당월_매출_건수  ...    집객시설_수  총_직장_인구_수  아파트_단지_수
# 1441  0.023829  0.003046  0.009839  ...  0.020236   0.001717  0.014831
# 2948  0.102332  0.004390  0.010833  ...  0.008432   0.000534  0.036017
# 4092  0.023757  0.001256  0.002584  ...  0.011804   0.003262  0.008475
# 640   0.243219  0.020746  0.036029  ...  0.013491   0.017648  0.186441
# 4446  0.003545  0.011013  0.009827  ...  0.052277   0.025785  0.002119
#
# [5 rows x 9 columns]

# %%
test.head()
# Out:
#       기준_년_코드  기준_분기_코드    상권_코드  ... 총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 3422     2020         1  1001034  ...    1690.0      20.0         1
# 895      2020         3  1000590  ...     653.0       2.0         1
# 3565     2020         1  1000891  ...     589.0      49.0         0
# 1030     2020         3  1000455  ...      67.0      23.0         0
# 3890     2020         1  1000565  ...     245.0      63.0         0
#
# [5 rows x 14 columns]

# %%
test_1 = test.drop(['총_유동인구_수','당월_매출_금액','당월_매출_건수','점포_수','개업_점포_수','폐업_점포_수','집객시설_수','총_직장_인구_수','아파트_단지_수','상권_변화_지표'], axis=1)
test_1
# Out:
#       기준_년_코드  기준_분기_코드    상권_코드     상권_코드_명
# 3422     2020         1  1001034  서울 서초구 방배역
# 895      2020         3  1000590     방화대로6라길
# 3565     2020         1  1000891      개포로28길
# 1030     2020         3  1000455      통일로39길
# 3890     2020         1  1000565      강서로5라길
# ...       ...       ...      ...         ...
# 1678     2020         2  1001295        행당시장
# 3660     2020         1  1000795   남부순환로142길
# 1783     2020         2  1001188    장충동 족발거리
# 4445     2020         1  1000010      성균관로5길
# 1093     2020         3  1000392      갈현로41길
#
# [1336 rows x 4 columns]

# %%
test_2 = test.drop(['기준_년_코드','기준_분기_코드','상권_코드','상권_코드_명'], axis=1)
test_2
# Out:
#       총_유동인구_수      당월_매출_금액   당월_매출_건수  ...  총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 3422  506520.0  3.878918e+10  1757971.0  ...     1690.0      20.0         1
# 895   646756.0  1.752883e+10   318927.0  ...      653.0       2.0         1
# 3565  474597.0  7.150946e+09   255715.0  ...      589.0      49.0         0
# 1030  854531.0  2.730511e+09   132723.0  ...       67.0      23.0         0
# 3890  685508.0  2.582417e+09    81202.0  ...      245.0      63.0         0
# ...        ...           ...        ...  ...        ...       ...       ...
# 1678  388249.0  1.644505e+10   675230.0  ...      314.0       1.0         1
# 3660  542861.0  3.805486e+09   165446.0  ...      418.0      58.0         0
# 1783  161802.0  6.573359e+09   403176.0  ...     2100.0       2.0         1
# 4445  450412.0  2.263473e+09   145504.0  ...      148.0      12.0         1
# 1093  519689.0  1.454083e+09   143985.0  ...      171.0      60.0         1
#
# [1336 rows x 10 columns]

# %%
scaler = MinMaxScaler()
test_2[:] = scaler.fit_transform(test_2[:])

# %%
test_2
# Out:
#       총_유동인구_수  당월_매출_금액  당월_매출_건수  ...  총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 3422  0.092483  0.121941  0.140989  ...   0.016121  0.042373       1.0
# 895   0.118533  0.055034  0.025493  ...   0.006229  0.004237       1.0
# 3565  0.086553  0.022375  0.020420  ...   0.005619  0.103814       0.0
# 1030  0.157129  0.008464  0.010549  ...   0.000639  0.048729       0.0
# 3890  0.125732  0.007997  0.006414  ...   0.002337  0.133475       0.0
# ...        ...       ...       ...  ...        ...       ...       ...
# 1678  0.070514  0.051623  0.054090  ...   0.002995  0.002119       1.0
# 3660  0.099234  0.011847  0.013175  ...   0.003987  0.122881       0.0
# 1783  0.028449  0.020557  0.032255  ...   0.020032  0.004237       1.0
# 4445  0.082061  0.006994  0.011574  ...   0.001412  0.025424       1.0
# 1093  0.094930  0.004447  0.011453  ...   0.001631  0.127119       1.0
#
# [1336 rows x 10 columns]

# %%
test_3 = pd.concat([test_1,test_2],axis=1)
test_3
# Out:
#       기준_년_코드  기준_분기_코드    상권_코드  ... 총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 3422     2020         1  1001034  ...  0.016121  0.042373       1.0
# 895      2020         3  1000590  ...  0.006229  0.004237       1.0
# 3565     2020         1  1000891  ...  0.005619  0.103814       0.0
# 1030     2020         3  1000455  ...  0.000639  0.048729       0.0
# 3890     2020         1  1000565  ...  0.002337  0.133475       0.0
# ...       ...       ...      ...  ...       ...       ...       ...
# 1678     2020         2  1001295  ...  0.002995  0.002119       1.0
# 3660     2020         1  1000795  ...  0.003987  0.122881       0.0
# 1783     2020         2  1001188  ...  0.020032  0.004237       1.0
# 4445     2020         1  1000010  ...  0.001412  0.025424       1.0
# 1093     2020         3  1000392  ...  0.001631  0.127119       1.0
#
# [1336 rows x 14 columns]

# %%
test_3 = test_3.set_index(["기준_년_코드", "기준_분기_코드", "상권_코드", "상권_코드_명"])
test_3
# Out:
#                                      총_유동인구_수  당월_매출_금액  ...  아파트_단지_수  상권_변화_지표
# 기준_년_코드 기준_분기_코드 상권_코드   상권_코드_명                         ...
# 2020    1        1001034 서울 서초구 방배역  0.092483  0.121941  ...  0.042373       1.0
#         3        1000590 방화대로6라길     0.118533  0.055034  ...  0.004237       1.0
#         1        1000891 개포로28길      0.086553  0.022375  ...  0.103814       0.0
#         3        1000455 통일로39길      0.157129  0.008464  ...  0.048729       0.0
#         1        1000565 강서로5라길      0.125732  0.007997  ...  0.133475       0.0
# ...                                       ...       ...  ...       ...       ...
#         2        1001295 행당시장        0.070514  0.051623  ...  0.002119       1.0
#         1        1000795 남부순환로142길   0.099234  0.011847  ...  0.122881       0.0
#         2        1001188 장충동 족발거리    0.028449  0.020557  ...  0.004237       1.0
#         1        1000010 성균관로5길      0.082061  0.006994  ...  0.025424       1.0
# ...

# %%
train_data = train_data.set_index(["총_유동인구_수"])
train_data
# Out:
#           당월_매출_금액  당월_매출_건수      점포_수  ...    집객시설_수  총_직장_인구_수  아파트_단지_수
# 총_유동인구_수                                ...
# 0.023829  0.003046  0.009839  0.010968  ...  0.020236   0.001717  0.014831
# 0.102332  0.004390  0.010833  0.005006  ...  0.008432   0.000534  0.036017
# 0.023757  0.001256  0.002584  0.004637  ...  0.011804   0.003262  0.008475
# 0.243219  0.020746  0.036029  0.024218  ...  0.013491   0.017648  0.186441
# 0.003545  0.011013  0.009827  0.011189  ...  0.052277   0.025785  0.002119
# ...            ...       ...       ...  ...       ...        ...       ...
# 0.070407  0.011397  0.047163  0.008171  ...  0.010118   0.001431  0.016949
# 0.046462  0.013356  0.023967  0.011999  ...  0.013491   0.004226  0.014831
# 0.213356  0.004697  0.012760  0.009275  ...  0.023609   0.001984  0.031780
# 0.011394  0.882935  0.129503  0.071034  ...  0.011804   0.003739  0.002119
# 0.258827  0.097210  0.140208  0.049908  ...  0.172007   0.021788  0.052966
#
# [3118 rows x 8 columns]

# %%
train = train.set_index(["총_유동인구_수"])
train
# Out:
#           당월_매출_금액  당월_매출_건수      점포_수  ...  총_직장_인구_수  아파트_단지_수  상권_변화_지표
# 총_유동인구_수                                ...
# 0.023829  0.003046  0.009839  0.010968  ...   0.001717  0.014831       1.0
# 0.102332  0.004390  0.010833  0.005006  ...   0.000534  0.036017       1.0
# 0.023757  0.001256  0.002584  0.004637  ...   0.003262  0.008475       1.0
# 0.243219  0.020746  0.036029  0.024218  ...   0.017648  0.186441       1.0
# 0.003545  0.011013  0.009827  0.011189  ...   0.025785  0.002119       1.0
# ...            ...       ...       ...  ...        ...       ...       ...
# 0.070407  0.011397  0.047163  0.008171  ...   0.001431  0.016949       1.0
# 0.046462  0.013356  0.023967  0.011999  ...   0.004226  0.014831       1.0
# 0.213356  0.004697  0.012760  0.009275  ...   0.001984  0.031780       1.0
# 0.011394  0.882935  0.129503  0.071034  ...   0.003739  0.002119       1.0
# 0.258827  0.097210  0.140208  0.049908  ...   0.021788  0.052966       1.0
#
# [3118 rows x 9 columns]

# %%
train.to_csv("/content/drive/My Drive/Colab Notebooks/seouldata/train_f.csv")

# %%
train_data.to_csv("/content/drive/My Drive/Colab Notebooks/seouldata/train_data_f.csv")

# %%
test_3.to_csv("/content/drive/My Drive/Colab Notebooks/seouldata/test_f.csv")
